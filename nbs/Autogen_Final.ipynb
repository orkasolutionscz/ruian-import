# %% [markdown]
# ## How to get started:
#
# 1. Download / Clone the [Repo](https://kirr.co/0bu8v5)
# 2. Activate a virtual environment `python3 -m venv .`
# 3. Run `pip install -r requirements.txt`
# 4. Run `jupyter notebook`
#
# > If you get a import error related to django, just do steps 2-4 in a new terminal / powershell.

# %%
# !pip freeze

# %%
from django_setup import init_django
init_django('autogen')

# %%
from sqlalchemy import create_engine
sql_engine = create_engine("sqlite:///ruian.sqlite3")

# %%
import pathlib
import pandas as pd

# %%
ROOT_DIR = pathlib.Path().resolve()
print(ROOT_DIR)
NBS_DIR = ROOT_DIR / "nbs" 
DATA_DIR = ROOT_DIR / "data"
# Out:
# /home/spravce/Rapidnet/ruian-import

# %%
ruian_csv = DATA_DIR / '20201031_OB_598917_ADR.csv' # scrape stackoverflow
ruian_csv.exists()
# Out:
# True

# %%
df = pd.read_csv(ruian_csv, encoding='Windows-1250', sep=';')
df.columns = ['kod_adm', 'kod_obce', 'nazev_obce', 'kod_momc', 'nazev_momc',
       'kod_mop', 'nazev_mop', 'kod_casti_obce', 'nazev_casti_obce',
       'kod_ulice', 'nazev_ulice', 'typ_so', 'cislo_domovni',
       'cislo_orientacni', 'znak_cisla_orientacniho', 'psc', 'souradnice_y',
       'souradnice_x', 'plati_od']
print(df.columns)
# Out:
# Index(['kod_adm', 'kod_obce', 'nazev_obce', 'kod_momc', 'nazev_momc',
#        'kod_mop', 'nazev_mop', 'kod_casti_obce', 'nazev_casti_obce',
#        'kod_ulice', 'nazev_ulice', 'typ_so', 'cislo_domovni',
#        'cislo_orientacni', 'znak_cisla_orientacniho', 'psc', 'souradnice_y',
#        'souradnice_x', 'plati_od'],
#       dtype='object')

# %%
df.head()
# Out:
#     kod_adm  kod_obce nazev_obce  kod_momc  nazev_momc  kod_mop  nazev_mop  \
# 0  23238291    598917    Karviná       NaN         NaN      NaN        NaN
# 1  23238305    598917    Karviná       NaN         NaN      NaN        NaN
# 2  23238321    598917    Karviná       NaN         NaN      NaN        NaN
# 3  23238330    598917    Karviná       NaN         NaN      NaN        NaN
# 4  23238348    598917    Karviná       NaN         NaN      NaN        NaN
#
#    kod_casti_obce nazev_casti_obce  kod_ulice nazev_ulice typ_so  \
# 0          413402          Mizerov   198897.0  Borovského   č.p.
# 1          413402          Mizerov   199681.0    Na Kopci   č.p.
# 2          413411       Nové Město   198960.0     Cihelní   č.p.
# 3          413411       Nové Město   200191.0  Sokolovská   č.p.
# 4          413429              Ráj   200581.0     V Aleji   č.p.
#
#    cislo_domovni  cislo_orientacni znak_cisla_orientacniho    psc  \
# 0           2007              59.0                     NaN  73401
# 1           2058               2.0                     NaN  73401
# 2           1656              19.0                     NaN  73506
# 3           1761              36.0                     NaN  73506
# 4            648              31.0                     NaN  73401
#
#    souradnice_y  souradnice_x             plati_od
# 0     450542.06    1101183.40  2013-11-29T00:00:00
# 1     450220.00    1101190.00  2013-11-29T00:00:00
# 2     452303.86    1100361.21  2013-11-29T00:00:00
# 3     451570.95    1100501.62  2013-11-29T00:00:00
# 4     450540.35    1101519.35  2013-11-29T00:00:00

# %%
df.to_sql(name='ruian', if_exists='replace', con=sql_engine)

# %%
# !python manage.py inspectdb --database ruian
# Out:
# # This is an auto-generated Django model module.
# # You'll have to do the following manually to clean this up:
# #   * Rearrange models' order
# #   * Make sure each model has one field with primary_key=True
# #   * Make sure each ForeignKey and OneToOneField has `on_delete` set to the desired behavior
# #   * Remove `managed = False` lines if you wish to allow Django to create, modify, and delete the table
# # Feel free to rename the models, but don't rename db_table values or field names.
# from django.db import models
#
#
# class Ruian(models.Model):
#     index = models.BigIntegerField(blank=True, null=True)
#     kod_adm = models.BigIntegerField(blank=True, null=True)
#     kod_obce = models.BigIntegerField(blank=True, null=True)
#     nazev_obce = models.TextField(blank=True, null=True)
#     kod_momc = models.TextField(blank=True, null=True)  # This field type is a guess.
#     nazev_momc = models.TextField(blank=True, null=True)  # This field type is a guess.
#     kod_mop = models.TextField(blank=True, null=True)  # This field type is a guess.
#     nazev_mop = models.TextField(blank=True, null=True)  # This field type is a guess.
#     kod_casti_obce = models.BigIntegerField(blank=True, null=True)
#     nazev_casti_obce = models.TextField(blank=True, null=True)
#     kod_ulice = models.TextField(blank=True, null=True)  # This field type is a guess.
#     nazev_ulice = models.TextField(blank=True, null=True)
#     typ_so = models.TextField(blank=True, null=True)
#     cislo_domovni = models.BigIntegerField(blank=True, null=True)
#     cislo_orientacni = models.TextField(blank=True, null=True)  # This field type is a guess.
#     znak_cisla_orientacniho = models.TextField(blank=True, null=True)
#     psc = models.BigIntegerField(blank=True, null=True)
#     souradnice_y = models.TextField(blank=True, null=True)  # This field type is a guess.
#     souradnice_x = models.TextField(blank=True, null=True)  # This field type is a guess.
#     plati_od = models.TextField(blank=True, null=True)
#
#     class Meta:
#         managed = False
#         db_table = 'ruian'

# %%
# !python manage.py startapp ruian

# %%
# !python manage.py makemigrations
# !python manage.py migrate
# Out:
# No changes detected
# Operations to perform:
#   Apply all migrations: admin, auth, contenttypes, ruian, sessions
# Running migrations:
#   No migrations to apply.

# %%
from ruian.models import Ruian

# %%
new_data = df.to_dict('records')
new_data
# Out:
# [{'kod_adm': 23238291,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 198897.0,
#   'nazev_ulice': 'Borovského',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2007,
#   'cislo_orientacni': 59.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 450542.06,
#   'souradnice_x': 1101183.4,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 23238305,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199681.0,
#   'nazev_ulice': 'Na Kopci',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2058,
#   'cislo_orientacni': 2.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 450220.0,
#   'souradnice_x': 1101190.0,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 23238321,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413411,
#   'nazev_casti_obce': 'Nové Město',
#   'kod_ulice': 198960.0,
#   'nazev_ulice': 'Cihelní',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 1656,
#   'cislo_orientacni': 19.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73506,
#   'souradnice_y': 452303.86,
#   'souradnice_x': 1100361.21,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 23238330,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413411,
#   'nazev_casti_obce': 'Nové Město',
#   'kod_ulice': 200191.0,
#   'nazev_ulice': 'Sokolovská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 1761,
#   'cislo_orientacni': 36.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73506,
#   'souradnice_y': 451570.95,
#   'souradnice_x': 1100501.62,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 23238348,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413429,
#   'nazev_casti_obce': 'Ráj',
#   'kod_ulice': 200581.0,
#   'nazev_ulice': 'V Aleji',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 648,
#   'cislo_orientacni': 31.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 450540.35,
#   'souradnice_x': 1101519.35,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24206911,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 63924,
#   'nazev_casti_obce': 'Hranice',
#   'kod_ulice': 200174.0,
#   'nazev_ulice': 'Slovenská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2941,
#   'cislo_orientacni': 31.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 450819.05,
#   'souradnice_x': 1099731.72,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24206920,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 63924,
#   'nazev_casti_obce': 'Hranice',
#   'kod_ulice': 200174.0,
#   'nazev_ulice': 'Slovenská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2943,
#   'cislo_orientacni': 23.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 450744.12,
#   'souradnice_x': 1099705.46,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24206946,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 200395.0,
#   'nazev_ulice': 'tř. Těreškovové',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2043,
#   'cislo_orientacni': 4.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 450708.74,
#   'souradnice_x': 1101114.68,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24206954,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199681.0,
#   'nazev_ulice': 'Na Kopci',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2073,
#   'cislo_orientacni': 17.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 450286.65,
#   'souradnice_x': 1101064.48,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24206962,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199401.0,
#   'nazev_ulice': 'Kpt. Jaroše',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2171,
#   'cislo_orientacni': 9.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 450611.59,
#   'souradnice_x': 1100668.09,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24206971,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413411,
#   'nazev_casti_obce': 'Nové Město',
#   'kod_ulice': 199095.0,
#   'nazev_ulice': 'Fibichova',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 1595,
#   'cislo_orientacni': 15.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73506,
#   'souradnice_y': 452236.29,
#   'souradnice_x': 1100109.42,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24206989,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413411,
#   'nazev_casti_obce': 'Nové Město',
#   'kod_ulice': 200743.0,
#   'nazev_ulice': 'Závodní',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2423,
#   'cislo_orientacni': 33.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73506,
#   'souradnice_y': 451753.18,
#   'souradnice_x': 1100176.1,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24206997,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413429,
#   'nazev_casti_obce': 'Ráj',
#   'kod_ulice': 200468.0,
#   'nazev_ulice': 'U Lesa',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 720,
#   'cislo_orientacni': 6.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 450520.53,
#   'souradnice_x': 1101844.44,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207004,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 63924,
#   'nazev_casti_obce': 'Hranice',
#   'kod_ulice': 199222.0,
#   'nazev_ulice': 'Hraničářská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 142,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 449753.63,
#   'souradnice_x': 1099605.42,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207012,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 63924,
#   'nazev_casti_obce': 'Hranice',
#   'kod_ulice': 199222.0,
#   'nazev_ulice': 'Hraničářská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 143,
#   'cislo_orientacni': 3.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 449751.22,
#   'souradnice_x': 1099584.54,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207021,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 63924,
#   'nazev_casti_obce': 'Hranice',
#   'kod_ulice': 199222.0,
#   'nazev_ulice': 'Hraničářská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 411,
#   'cislo_orientacni': 2.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 449717.36,
#   'souradnice_x': 1099582.92,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207039,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 63924,
#   'nazev_casti_obce': 'Hranice',
#   'kod_ulice': 199605.0,
#   'nazev_ulice': 'Mickiewiczova',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 429,
#   'cislo_orientacni': 109.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 449833.94,
#   'souradnice_x': 1099615.2,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207063,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 63924,
#   'nazev_casti_obce': 'Hranice',
#   'kod_ulice': 200638.0,
#   'nazev_ulice': 'Včelařská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 472,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 449549.58,
#   'souradnice_x': 1099462.48,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207071,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 63924,
#   'nazev_casti_obce': 'Hranice',
#   'kod_ulice': 200816.0,
#   'nazev_ulice': 'U Vodárny',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 483,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 450960.1,
#   'souradnice_x': 1099095.57,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207080,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 63924,
#   'nazev_casti_obce': 'Hranice',
#   'kod_ulice': 199338.0,
#   'nazev_ulice': 'Kašparova',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 503,
#   'cislo_orientacni': 2.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 450756.38,
#   'souradnice_x': 1099513.19,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207098,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 63924,
#   'nazev_casti_obce': 'Hranice',
#   'kod_ulice': 199451.0,
#   'nazev_ulice': 'Leonovova',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 1795,
#   'cislo_orientacni': 3.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451048.59,
#   'souradnice_x': 1099980.2,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207101,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 63924,
#   'nazev_casti_obce': 'Hranice',
#   'kod_ulice': 200760.0,
#   'nazev_ulice': 'Žižkova',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 1818,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': 'a',
#   'psc': 73301,
#   'souradnice_y': 451181.01,
#   'souradnice_x': 1100251.51,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207110,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 63924,
#   'nazev_casti_obce': 'Hranice',
#   'kod_ulice': 201189.0,
#   'nazev_ulice': 'Modřínová',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 1961,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 449548.87,
#   'souradnice_x': 1099680.49,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207128,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 63924,
#   'nazev_casti_obce': 'Hranice',
#   'kod_ulice': 200760.0,
#   'nazev_ulice': 'Žižkova',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2800,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 450831.35,
#   'souradnice_x': 1100108.52,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207136,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 63924,
#   'nazev_casti_obce': 'Hranice',
#   'kod_ulice': 198919.0,
#   'nazev_ulice': 'Bratr. Veverkových',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2805,
#   'cislo_orientacni': 2.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 450701.62,
#   'souradnice_x': 1100015.58,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207144,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 63924,
#   'nazev_casti_obce': 'Hranice',
#   'kod_ulice': 199109.0,
#   'nazev_ulice': 'Flemingova',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2846,
#   'cislo_orientacni': 3.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 450532.97,
#   'souradnice_x': 1099977.5,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207152,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 63924,
#   'nazev_casti_obce': 'Hranice',
#   'kod_ulice': 199109.0,
#   'nazev_ulice': 'Flemingova',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2847,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 450525.34,
#   'souradnice_x': 1099992.63,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207161,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 63924,
#   'nazev_casti_obce': 'Hranice',
#   'kod_ulice': 199010.0,
#   'nazev_ulice': 'Čsl. armády',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2856,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 450436.03,
#   'souradnice_x': 1099904.38,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207179,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 63924,
#   'nazev_casti_obce': 'Hranice',
#   'kod_ulice': 199010.0,
#   'nazev_ulice': 'Čsl. armády',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2857,
#   'cislo_orientacni': 3.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 450440.09,
#   'souradnice_x': 1099887.75,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207187,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 63924,
#   'nazev_casti_obce': 'Hranice',
#   'kod_ulice': 199591.0,
#   'nazev_ulice': 'Mendelova',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2937,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 450886.78,
#   'souradnice_x': 1099810.74,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207195,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 64190,
#   'nazev_casti_obce': 'Staré Město',
#   'kod_ulice': 199982.0,
#   'nazev_ulice': 'Požárnická',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 453716.27,
#   'souradnice_x': 1100230.99,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207217,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 64190,
#   'nazev_casti_obce': 'Staré Město',
#   'kod_ulice': 199184.0,
#   'nazev_ulice': 'Hlíny',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 89,
#   'cislo_orientacni': 3.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 453082.67,
#   'souradnice_x': 1098885.46,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207225,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 64190,
#   'nazev_casti_obce': 'Staré Město',
#   'kod_ulice': 199184.0,
#   'nazev_ulice': 'Hlíny',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 158,
#   'cislo_orientacni': 2.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 453120.2,
#   'souradnice_x': 1098940.21,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207233,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 64190,
#   'nazev_casti_obce': 'Staré Město',
#   'kod_ulice': 200221.0,
#   'nazev_ulice': 'Staroměstská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 231,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 453588.79,
#   'souradnice_x': 1099186.98,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207241,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 64190,
#   'nazev_casti_obce': 'Staré Město',
#   'kod_ulice': 199478.0,
#   'nazev_ulice': 'Lešetínská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 249,
#   'cislo_orientacni': 3.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 453655.69,
#   'souradnice_x': 1100429.07,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207250,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 64190,
#   'nazev_casti_obce': 'Staré Město',
#   'kod_ulice': 199478.0,
#   'nazev_ulice': 'Lešetínská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 252,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 453674.34,
#   'souradnice_x': 1100420.08,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207276,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 64190,
#   'nazev_casti_obce': 'Staré Město',
#   'kod_ulice': 198889.0,
#   'nazev_ulice': 'Bohumínská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 273,
#   'cislo_orientacni': 11.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 454265.17,
#   'souradnice_x': 1098847.21,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207306,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 64190,
#   'nazev_casti_obce': 'Staré Město',
#   'kod_ulice': 199184.0,
#   'nazev_ulice': 'Hlíny',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 351,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 453119.25,
#   'souradnice_x': 1098901.18,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207314,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199915.0,
#   'nazev_ulice': 'Pivovarská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 452019.0,
#   'souradnice_x': 1101107.31,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207322,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 200280.0,
#   'nazev_ulice': 'Svatováclavská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 31,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451858.82,
#   'souradnice_x': 1101002.5,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207349,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199559.0,
#   'nazev_ulice': 'Markova',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 48,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451780.28,
#   'souradnice_x': 1100962.48,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207357,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 200727.0,
#   'nazev_ulice': 'Zámecká',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 96,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451848.75,
#   'souradnice_x': 1101126.46,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207365,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 198846.0,
#   'nazev_ulice': 'Akátová',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 198,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451430.76,
#   'souradnice_x': 1101540.98,
#   'plati_od': '2014-06-05T00:00:00'},
#  {'kod_adm': 24207373,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199320.0,
#   'nazev_ulice': 'Poštovní',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 616,
#   'cislo_orientacni': 3.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451675.23,
#   'souradnice_x': 1100905.68,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207381,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199320.0,
#   'nazev_ulice': 'Poštovní',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 617,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451685.14,
#   'souradnice_x': 1100918.43,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207403,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199311.0,
#   'nazev_ulice': 'Karola Śliwky',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 622,
#   'cislo_orientacni': 3.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451839.35,
#   'souradnice_x': 1100886.06,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207411,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 200263.0,
#   'nazev_ulice': 'Svatopluka Čecha',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 736,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 452164.07,
#   'souradnice_x': 1100785.09,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207420,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199737.0,
#   'nazev_ulice': 'Nádražní',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 764,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 452770.47,
#   'souradnice_x': 1101025.05,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207438,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199231.0,
#   'nazev_ulice': 'Husova',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 772,
#   'cislo_orientacni': 2.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 452339.19,
#   'souradnice_x': 1101068.29,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207446,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199206.0,
#   'nazev_ulice': 'Hornická stezka',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 780,
#   'cislo_orientacni': 2.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 452241.36,
#   'souradnice_x': 1100930.64,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207462,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199311.0,
#   'nazev_ulice': 'Karola Śliwky',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 783,
#   'cislo_orientacni': 2.0,
#   'znak_cisla_orientacniho': 'a',
#   'psc': 73301,
#   'souradnice_y': 452076.98,
#   'souradnice_x': 1100924.37,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207471,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199648.0,
#   'nazev_ulice': 'Mlýnská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 788,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451984.54,
#   'souradnice_x': 1100964.51,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207489,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199672.0,
#   'nazev_ulice': 'Na Bělidle',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 798,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 452099.34,
#   'souradnice_x': 1101087.42,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207497,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199575.0,
#   'nazev_ulice': 'Máchova',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 830,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 452268.76,
#   'souradnice_x': 1101169.41,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207501,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199231.0,
#   'nazev_ulice': 'Husova',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 835,
#   'cislo_orientacni': 3.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 452276.1,
#   'souradnice_x': 1101063.6,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207519,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 198854.0,
#   'nazev_ulice': 'Alšova',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 838,
#   'cislo_orientacni': 2.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 452326.84,
#   'souradnice_x': 1101093.12,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207527,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 198854.0,
#   'nazev_ulice': 'Alšova',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 839,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 452320.06,
#   'souradnice_x': 1101115.06,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207535,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 198854.0,
#   'nazev_ulice': 'Alšova',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 841,
#   'cislo_orientacni': 3.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 452334.54,
#   'souradnice_x': 1101125.37,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207543,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 198846.0,
#   'nazev_ulice': 'Akátová',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 1008,
#   'cislo_orientacni': 2.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451432.72,
#   'souradnice_x': 1101515.92,
#   'plati_od': '2014-06-05T00:00:00'},
#  {'kod_adm': 24207551,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 200701.0,
#   'nazev_ulice': 'Zahradní',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 1021,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 452338.23,
#   'souradnice_x': 1100815.34,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207560,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 200115.0,
#   'nazev_ulice': 'Sadová',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 1836,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451539.59,
#   'souradnice_x': 1101540.7,
#   'plati_od': '2014-06-05T00:00:00'},
#  {'kod_adm': 24207578,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 198846.0,
#   'nazev_ulice': 'Akátová',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 1841,
#   'cislo_orientacni': 3.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451535.96,
#   'souradnice_x': 1101622.55,
#   'plati_od': '2014-06-05T00:00:00'},
#  {'kod_adm': 24207586,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199478.0,
#   'nazev_ulice': 'Lešetínská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 1945,
#   'cislo_orientacni': 49.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 452987.64,
#   'souradnice_x': 1101090.43,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207624,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413399,
#   'nazev_casti_obce': 'Lázně Darkov',
#   'kod_ulice': 199435.0,
#   'nazev_ulice': 'Lázeňská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 297,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73503,
#   'souradnice_y': 451692.03,
#   'souradnice_x': 1101776.53,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207641,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 200697.0,
#   'nazev_ulice': 'Zahradnická',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 321,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 451293.37,
#   'souradnice_x': 1100743.56,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207659,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199974.0,
#   'nazev_ulice': 'Poutní',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 353,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 450277.27,
#   'souradnice_x': 1100423.78,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207667,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199605.0,
#   'nazev_ulice': 'Mickiewiczova',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 358,
#   'cislo_orientacni': 69.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 449426.59,
#   'souradnice_x': 1100274.69,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207675,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199249.0,
#   'nazev_ulice': 'Jindřicha Šimona Baara',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 379,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 449966.3,
#   'souradnice_x': 1100040.86,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207683,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199249.0,
#   'nazev_ulice': 'Jindřicha Šimona Baara',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 380,
#   'cislo_orientacni': 3.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 449993.88,
#   'souradnice_x': 1100001.53,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207691,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 198951.0,
#   'nazev_ulice': 'Chodská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 388,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 450068.91,
#   'souradnice_x': 1100093.27,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207705,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 198951.0,
#   'nazev_ulice': 'Chodská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 492,
#   'cislo_orientacni': 3.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 450090.71,
#   'souradnice_x': 1100049.45,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207713,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199613.0,
#   'nazev_ulice': 'Mizerovská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 907,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 450184.71,
#   'souradnice_x': 1100151.61,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207721,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 198951.0,
#   'nazev_ulice': 'Chodská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 1463,
#   'cislo_orientacni': 2.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 450049.16,
#   'souradnice_x': 1100080.16,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207730,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199842.0,
#   'nazev_ulice': 'Olšová',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 1493,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 451180.96,
#   'souradnice_x': 1100480.83,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207748,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 200760.0,
#   'nazev_ulice': 'Žižkova',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 1799,
#   'cislo_orientacni': 2.0,
#   'znak_cisla_orientacniho': 'a',
#   'psc': 73401,
#   'souradnice_y': 451285.65,
#   'souradnice_x': 1100491.46,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207756,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 200247.0,
#   'nazev_ulice': 'Studentská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 1800,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 451368.96,
#   'souradnice_x': 1100635.74,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207764,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199966.0,
#   'nazev_ulice': 'Potoční',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 1854,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 451115.78,
#   'souradnice_x': 1100449.34,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207772,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 200549.0,
#   'nazev_ulice': 'U Studny',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 1885,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 451035.73,
#   'souradnice_x': 1100879.05,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207781,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199460.0,
#   'nazev_ulice': 'Lesní',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 1915,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 450171.23,
#   'souradnice_x': 1100117.75,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207799,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199249.0,
#   'nazev_ulice': 'Jindřicha Šimona Baara',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 1945,
#   'cislo_orientacni': 2.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 449962.82,
#   'souradnice_x': 1099994.91,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207802,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199052.0,
#   'nazev_ulice': 'Družstevní',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 1962,
#   'cislo_orientacni': 3.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 449898.17,
#   'souradnice_x': 1099955.1,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207811,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199052.0,
#   'nazev_ulice': 'Družstevní',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 1963,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 449894.44,
#   'souradnice_x': 1099963.02,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207829,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199052.0,
#   'nazev_ulice': 'Družstevní',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 1964,
#   'cislo_orientacni': 2.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 449866.29,
#   'souradnice_x': 1099940.14,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207837,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 200000.0,
#   'nazev_ulice': 'Průkopnická',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 1979,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 449781.06,
#   'souradnice_x': 1099899.82,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207845,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199524.0,
#   'nazev_ulice': 'Majakovského',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2011,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 450470.12,
#   'souradnice_x': 1101155.3,
#   'plati_od': '2020-08-20T00:00:00'},
#  {'kod_adm': 24207853,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 198986.0,
#   'nazev_ulice': 'Čajkovského',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2017,
#   'cislo_orientacni': 3.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 450522.19,
#   'souradnice_x': 1101115.1,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207861,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 198986.0,
#   'nazev_ulice': 'Čajkovského',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2018,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 450521.36,
#   'souradnice_x': 1101096.79,
#   'plati_od': '2020-01-23T00:00:00'},
#  {'kod_adm': 24207870,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199681.0,
#   'nazev_ulice': 'Na Kopci',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2055,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 450265.38,
#   'souradnice_x': 1101195.16,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207888,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199401.0,
#   'nazev_ulice': 'Kpt. Jaroše',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2175,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 450664.38,
#   'souradnice_x': 1100680.82,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207896,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199273.0,
#   'nazev_ulice': 'Jasmínová',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2236,
#   'cislo_orientacni': 2.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 449668.65,
#   'souradnice_x': 1099855.29,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207900,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199273.0,
#   'nazev_ulice': 'Jasmínová',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2247,
#   'cislo_orientacni': 3.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 449709.23,
#   'souradnice_x': 1099845.34,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207918,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199273.0,
#   'nazev_ulice': 'Jasmínová',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2248,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 449699.33,
#   'souradnice_x': 1099865.64,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207926,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 200395.0,
#   'nazev_ulice': 'tř. Těreškovové',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2250,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 450758.35,
#   'souradnice_x': 1101134.79,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207934,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199346.0,
#   'nazev_ulice': 'Kirovova',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2307,
#   'cislo_orientacni': 2.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 451123.47,
#   'souradnice_x': 1101012.13,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207942,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199346.0,
#   'nazev_ulice': 'Kirovova',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2308,
#   'cislo_orientacni': 3.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 451127.83,
#   'souradnice_x': 1100970.88,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207951,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 199346.0,
#   'nazev_ulice': 'Kirovova',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2309,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 451146.54,
#   'souradnice_x': 1100982.65,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207969,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 200018.0,
#   'nazev_ulice': 'Příční',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2313,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 451162.17,
#   'souradnice_x': 1100877.53,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207977,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 198897.0,
#   'nazev_ulice': 'Borovského',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2315,
#   'cislo_orientacni': 1.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 451224.12,
#   'souradnice_x': 1101051.63,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24207985,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413402,
#   'nazev_casti_obce': 'Mizerov',
#   'kod_ulice': 198897.0,
#   'nazev_ulice': 'Borovského',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 2316,
#   'cislo_orientacni': 3.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73401,
#   'souradnice_y': 451094.94,
#   'souradnice_x': 1101073.25,
# ...
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199117.0,
#   'nazev_ulice': 'Fryštátská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 74,
#   'cislo_orientacni': 5.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451713.52,
#   'souradnice_x': 1101105.69,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229083,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199117.0,
#   'nazev_ulice': 'Fryštátská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 75,
#   'cislo_orientacni': 7.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451701.09,
#   'souradnice_x': 1101103.55,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229091,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 200280.0,
#   'nazev_ulice': 'Svatováclavská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 76,
#   'cislo_orientacni': 12.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451811.4,
#   'souradnice_x': 1100926.39,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229105,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 200280.0,
#   'nazev_ulice': 'Svatováclavská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 77,
#   'cislo_orientacni': 10.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451816.58,
#   'souradnice_x': 1100944.72,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229113,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 200280.0,
#   'nazev_ulice': 'Svatováclavská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 78,
#   'cislo_orientacni': 4.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451830.26,
#   'souradnice_x': 1100978.06,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229121,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199117.0,
#   'nazev_ulice': 'Fryštátská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 79,
#   'cislo_orientacni': 22.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451703.53,
#   'souradnice_x': 1101132.15,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229130,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199117.0,
#   'nazev_ulice': 'Fryštátská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 80,
#   'cislo_orientacni': 20.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451711.02,
#   'souradnice_x': 1101131.7,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229148,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199117.0,
#   'nazev_ulice': 'Fryštátská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 81,
#   'cislo_orientacni': 18.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451719.19,
#   'souradnice_x': 1101130.11,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229156,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199117.0,
#   'nazev_ulice': 'Fryštátská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 82,
#   'cislo_orientacni': 16.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451726.68,
#   'souradnice_x': 1101130.11,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229164,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199117.0,
#   'nazev_ulice': 'Fryštátská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 83,
#   'cislo_orientacni': 14.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451733.94,
#   'souradnice_x': 1101129.77,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229172,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199117.0,
#   'nazev_ulice': 'Fryštátská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 84,
#   'cislo_orientacni': 12.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451741.53,
#   'souradnice_x': 1101128.57,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229181,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199117.0,
#   'nazev_ulice': 'Fryštátská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 85,
#   'cislo_orientacni': 10.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451751.38,
#   'souradnice_x': 1101125.4,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229199,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199117.0,
#   'nazev_ulice': 'Fryštátská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 86,
#   'cislo_orientacni': 8.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451762.69,
#   'souradnice_x': 1101122.15,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229202,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199117.0,
#   'nazev_ulice': 'Fryštátská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 87,
#   'cislo_orientacni': 6.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451770.09,
#   'souradnice_x': 1101119.99,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229211,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199117.0,
#   'nazev_ulice': 'Fryštátská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 88,
#   'cislo_orientacni': 4.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451780.29,
#   'souradnice_x': 1101118.37,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229229,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199117.0,
#   'nazev_ulice': 'Fryštátská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 89,
#   'cislo_orientacni': 2.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451794.75,
#   'souradnice_x': 1101124.37,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229245,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199567.0,
#   'nazev_ulice': 'Masarykovo nám.',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 91,
#   'cislo_orientacni': 28.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451817.69,
#   'souradnice_x': 1101096.87,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229253,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199567.0,
#   'nazev_ulice': 'Masarykovo nám.',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 92,
#   'cislo_orientacni': 29.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451836.87,
#   'souradnice_x': 1101119.38,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229261,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199567.0,
#   'nazev_ulice': 'Masarykovo nám.',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 93,
#   'cislo_orientacni': 30.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451841.04,
#   'souradnice_x': 1101100.2,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229270,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199567.0,
#   'nazev_ulice': 'Masarykovo nám.',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 94,
#   'cislo_orientacni': 31.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451845.62,
#   'souradnice_x': 1101090.59,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229288,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 199567.0,
#   'nazev_ulice': 'Masarykovo nám.',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 95,
#   'cislo_orientacni': 32.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451859.8,
#   'souradnice_x': 1101097.28,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229296,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 200280.0,
#   'nazev_ulice': 'Svatováclavská',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 97,
#   'cislo_orientacni': 6.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451822.1,
#   'souradnice_x': 1100955.75,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229300,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 200727.0,
#   'nazev_ulice': 'Zámecká',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 98,
#   'cislo_orientacni': 5.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451749.87,
#   'souradnice_x': 1101159.27,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229318,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 200727.0,
#   'nazev_ulice': 'Zámecká',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 99,
#   'cislo_orientacni': 7.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451742.22,
#   'souradnice_x': 1101163.24,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229326,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 666378.0,
#   'nazev_ulice': 'Bělidlo',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 100,
#   'cislo_orientacni': 7.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 452645.25,
#   'souradnice_x': 1101229.73,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229334,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 200727.0,
#   'nazev_ulice': 'Zámecká',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 101,
#   'cislo_orientacni': 2.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451812.13,
#   'souradnice_x': 1101158.17,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229342,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 200727.0,
#   'nazev_ulice': 'Zámecká',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 102,
#   'cislo_orientacni': 4.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451802.72,
#   'souradnice_x': 1101161.69,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229351,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 200727.0,
#   'nazev_ulice': 'Zámecká',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 103,
#   'cislo_orientacni': 6.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451794.65,
#   'souradnice_x': 1101164.27,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229369,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 200727.0,
#   'nazev_ulice': 'Zámecká',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 104,
#   'cislo_orientacni': 8.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451786.89,
#   'souradnice_x': 1101168.1,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229377,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 200727.0,
#   'nazev_ulice': 'Zámecká',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 105,
#   'cislo_orientacni': 10.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451779.34,
#   'souradnice_x': 1101171.52,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229385,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 200727.0,
#   'nazev_ulice': 'Zámecká',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 106,
#   'cislo_orientacni': 12.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451772.72,
#   'souradnice_x': 1101173.79,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229393,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 200727.0,
#   'nazev_ulice': 'Zámecká',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 107,
#   'cislo_orientacni': 14.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451764.86,
#   'souradnice_x': 1101176.89,
#   'plati_od': '2013-11-29T00:00:00'},
#  {'kod_adm': 24229407,
#   'kod_obce': 598917,
#   'nazev_obce': 'Karviná',
#   'kod_momc': nan,
#   'nazev_momc': nan,
#   'kod_mop': nan,
#   'nazev_mop': nan,
#   'kod_casti_obce': 413381,
#   'nazev_casti_obce': 'Fryštát',
#   'kod_ulice': 200727.0,
#   'nazev_ulice': 'Zámecká',
#   'typ_so': 'č.p.',
#   'cislo_domovni': 108,
#   'cislo_orientacni': 16.0,
#   'znak_cisla_orientacniho': nan,
#   'psc': 73301,
#   'souradnice_y': 451743.68,
#   'souradnice_x': 1101186.5,
#   'plati_od': '2013-11-29T00:00:00'},
#  ...]

# %%
qs = Ruian.objects.all()
if qs.count() != 0:
    qs.delete()
    
new_entries = []
for d in new_data:
    new_obj = Ruian(**d)
    new_entries.append(new_obj)

Ruian.objects.bulk_create(new_entries)
# Out:
# [<Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  <Ruian: Ruian object (None)>,
#  ...]

# %%
qs = Ruian.objects.all()

# %%
qs.count() == df.shape[0]
# Out:
# True

# %%
qs.first().kod_adm
# Out:
# 23238291
